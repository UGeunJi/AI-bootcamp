# %%
pwd
# Out:
# 'C:\\Users\\Playdata\\Documents\\인공지능 25기\\Web Scraping'

# %% [markdown]
# **셀레니움**
# - 웹 페이지 테스트 자동화를 할 수 있는 프레임워크
# - 셀레니움을 사용하면 완전한 형태의 웹 페이지 소스를 볼 수 있기 때문에 scraping할 때 유용

# %% [markdown]
# **사용 예**
# - 자바 스크립트가 동적으로 만든 데이터를 scraping할 때
# - 사이트의 다양한 HTML 요소에 클릭, 키보드 입력 등 이벤트를 줄 때

# %% [markdown]
# **사용 방법**
# - 셀레니움을 사용하려면 사용 중인 웹 브라우저의 드라이버 파일을 다운로드 해야 함
# - 크롬 드라이버 파일 다운로드 받기
# ```
# chrome://version/버전 확인
# http://chromedriver.chromium.org/downloads에서 chrome 버전과 운영체제에 맞는 드라이버 다운로드 압축 푼 뒤 응용 프로그램을 현재 작업 디렉토리에 복사
# ```

# %% [markdown]
# - selenium 설치
# ```
# conda install selenium
# ```

# %% [markdown]
# **참고사이트**
# ```
# http://www,selenium.dev/documentation/webdriver
# ```

# %%
from IPython.display import Image
Image('webdriver.png')

# %% [markdown]
# **find_element_by_tag_name**

# %%
import selenium

# %%
from selenium import webdriver

# %%
driver = webdriver.Chrome() # driver가 있는 path를 넣어줄 수 있음

# %%
driver.get("http://naver.com")

# %%
# find_element_by_tag_name를 통해 a tag에 접근
# href 정보까지도 조회

elem = driver.find_element_by_tag_name('a')

elem.get_attribute('href')

# %%
# 여러 tag를 가져올 때는 find_elements_by_tag_name

elems = driver.find_elements_by_tag_name('a')
for elem in elems:
    print(elem.get_attribute('href'))
# Out:
# https://www.naver.com/#newsstand
# https://www.naver.com/#themecast
# https://www.naver.com/#timesquare
# https://www.naver.com/#shopcast
# https://www.naver.com/#account
# https://whale.naver.com/banner/details/security/?=main&wpid=RydDy7
# https://installer-whale.pstatic.net/downloads/banner/RydDy7/WhaleSetup.exe
# https://www.naver.com/
# https://help.naver.com/support/welcomePage/guide.help
# https://jr.naver.com/
# https://happybean.naver.com/
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# https://help.naver.com/support/alias/search/word/word_29.naver
# https://help.naver.com/support/alias/search/word/word_29.naver
# https://help.naver.com/support/service/main.help?serviceNo=605&categoryNo=1991
# https://www.naver.com/#
# https://www.naver.com/#
# https://help.naver.com/support/alias/search/word/word_16.naver
# https://www.naver.com/#
# https://help.naver.com/support/alias/search/word/word_16.naver
# https://nid.naver.com/nidlogin.login
# https://help.naver.com/support/alias/search/word/word_16.naver
# https://www.naver.com/#
# https://help.naver.com/alias/search/word/word_17.naver
# https://help.naver.com/support/contents/contents.help?serviceNo=605&categoryNo=18215
# https://www.naver.com/#
# https://mail.naver.com/
# https://section.cafe.naver.com/
# https://section.blog.naver.com/
# https://kin.naver.com/
# https://shopping.naver.com/
# https://shoppinglive.naver.com/home
# https://order.pay.naver.com/home
# https://tv.naver.com/
# https://dict.naver.com/
# https://news.naver.com/
# https://finance.naver.com/
# https://land.naver.com/
# https://map.naver.com/
# https://vibe.naver.com/
# https://search.shopping.naver.com/book/home
# https://comic.naver.com/
# https://www.naver.com/#
# https://www.naver.com/more.html
# https://www.naver.com/#
# https://www.naver.com/#
# https://www.naver.com/#
# https://weather.naver.com/today/09650108?cpName=KMA
# https://me.naver.com/tab/news.nhn
# https://weather.naver.com/
# https://mycar.naver.com/
# https://game.naver.com/
# https://booking.naver.com/booked/list
# https://contents.premium.naver.com/
# http://plus.naver.com/
# https://news.naver.com/
# https://datalab.naver.com/
# https://search.shopping.naver.com/book/home
# https://memo.naver.com/
# https://band.us/
# https://land.naver.com/
# https://sports.news.naver.com/
# https://series.naver.com/
# https://serieson.naver.com/
# https://expert.naver.com/
# https://movie.naver.com/
# https://audioclip.naver.com/
# https://office.naver.com/
# https://whale.naver.com/
# https://novel.naver.com/
# https://comic.naver.com/
# https://in.naver.com/
# https://contact.naver.com/
# https://finance.naver.com/
# https://map.naver.com/
# https://terms.naver.com/
# https://calendar.naver.com/
# https://clovadubbing.naver.com/
# https://papago.naver.com/
# https://post.naver.com/
# https://academic.naver.com/
# https://flight.naver.com/
# https://hotels.naver.com/
# https://keep.naver.com/
# https://www.modoo.at/
# https://mybox.naver.com/
# https://entertain.naver.com/home
# https://www.vlive.tv/
# https://vibe.naver.com/
# https://dict.naver.com/
# https://ko.dict.naver.com/
# https://endic.naver.com/
# https://ja.dict.naver.com/
# https://zh.dict.naver.com/
# https://hanja.dict.naver.com/
# https://dict.naver.com/
# https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y
# ---------------------------------------------------------------------------
# StaleElementReferenceException            Traceback (most recent call last)
# Input In [40], in <cell line: 2>()
#       1 elems = driver.find_elements_by_tag_name('a')
#       2 for elem in elems:
# ----> 3     print(elem.get_attribute('href'))
#
# File ~\anaconda3_NR\lib\site-packages\selenium\webdriver\remote\webelement.py:139, in WebElement.get_attribute(self, name)
#     137 attributeValue = ''
#     138 if self._w3c:
# --> 139     attributeValue = self.parent.execute_script(
#     140         "return (%s).apply(null, arguments);" % getAttribute_js,
#     141         self, name)
#     142 else:
#     143     resp = self._execute(Command.GET_ELEMENT_ATTRIBUTE, {'name': name})
#
# File ~\anaconda3_NR\lib\site-packages\selenium\webdriver\remote\webdriver.py:634, in WebDriver.execute_script(self, script, *args)
#     631 else:
#     632     command = Command.EXECUTE_SCRIPT
# --> 634 return self.execute(command, {
#     635     'script': script,
#     636     'args': converted_args})['value']
#
# File ~\anaconda3_NR\lib\site-packages\selenium\webdriver\remote\webdriver.py:321, in WebDriver.execute(self, driver_command, params)
#     319 response = self.command_executor.execute(driver_command, params)
#     320 if response:
# --> 321     self.error_handler.check_response(response)
#     322     response['value'] = self._unwrap_value(
#     323         response.get('value', None))
#     324     return response
#
# File ~\anaconda3_NR\lib\site-packages\selenium\webdriver\remote\errorhandler.py:242, in ErrorHandler.check_response(self, response)
#     240         alert_text = value['alert'].get('text')
#     241     raise exception_class(message, screen, stacktrace, alert_text)
# --> 242 raise exception_class(message, screen, stacktrace)
#
# StaleElementReferenceException: Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=106.0.5249.119)

# %%
driver.quit()

# %%
driver.back()

# %%
driver.forward()

# %%
driver.refresh()

# %%
driver.close()  # brower가 종료
# Out:
# Exception ignored in: <function Service.__del__ at 0x0000024DD3B040D0>
# Traceback (most recent call last):
#   File "C:\Users\Playdata\anaconda3_NR\lib\site-packages\selenium\webdriver\common\service.py", line 176, in __del__
#     self.stop()
#   File "C:\Users\Playdata\anaconda3_NR\lib\site-packages\selenium\webdriver\common\service.py", line 151, in stop
#     self.send_remote_shutdown_command()
#   File "C:\Users\Playdata\anaconda3_NR\lib\site-packages\selenium\webdriver\common\service.py", line 132, in send_remote_shutdown_command
#     if not self.is_connectable():
#   File "C:\Users\Playdata\anaconda3_NR\lib\site-packages\selenium\webdriver\common\service.py", line 115, in is_connectable
#     return utils.is_connectable(self.port)
#   File "C:\Users\Playdata\anaconda3_NR\lib\site-packages\selenium\webdriver\common\utils.py", line 106, in is_connectable
#     socket_ = socket.create_connection((host, port), 1)
#   File "C:\Users\Playdata\anaconda3_NR\lib\socket.py", line 832, in create_connection
#     sock.connect(sa)
# KeyboardInterrupt:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [34], in <cell line: 1>()
# ----> 1 driver.close()
#
# File ~\anaconda3_NR\lib\site-packages\selenium\webdriver\remote\webdriver.py:688, in WebDriver.close(self)
#     681 def close(self):
#     682     """
#     683     Closes the current window.
#     684
#     685     :Usage:
#     686         driver.close()
#     687     """
# --> 688     self.execute(Command.CLOSE)
#
# File ~\anaconda3_NR\lib\site-packages\selenium\webdriver\remote\webdriver.py:319, in WebDriver.execute(self, driver_command, params)
#     316         params['sessionId'] = self.session_id
#     318 params = self._wrap_value(params)
# --> 319 response = self.command_executor.execute(driver_command, params)
#     320 if response:
#     321     self.error_handler.check_response(response)
#
# File ~\anaconda3_NR\lib\site-packages\selenium\webdriver\remote\remote_connection.py:374, in RemoteConnection.execute(self, command, params)
#     372 data = utils.dump_json(params)
#     373 url = '%s%s' % (self._url, path)
# --> 374 return self._request(command_info[0], url, body=data)
#
# File ~\anaconda3_NR\lib\site-packages\selenium\webdriver\remote\remote_connection.py:397, in RemoteConnection._request(self, method, url, body)
#     394     body = None
#     396 if self.keep_alive:
# --> 397     resp = self._conn.request(method, url, body=body, headers=headers)
#     399     statuscode = resp.status
#     400 else:
#
# File ~\anaconda3_NR\lib\site-packages\urllib3\request.py:74, in RequestMethods.request(self, method, url, fields, headers, **urlopen_kw)
#      71 urlopen_kw["request_url"] = url
#      73 if method in self._encode_url_methods:
# ---> 74     return self.request_encode_url(
#      75         method, url, fields=fields, headers=headers, **urlopen_kw
#      76     )
#      77 else:
#      78     return self.request_encode_body(
#      79         method, url, fields=fields, headers=headers, **urlopen_kw
#      80     )
#
# File ~\anaconda3_NR\lib\site-packages\urllib3\request.py:96, in RequestMethods.request_encode_url(self, method, url, fields, headers, **urlopen_kw)
#      93 if fields:
#      94     url += "?" + urlencode(fields)
# ---> 96 return self.urlopen(method, url, **extra_kw)
#
# File ~\anaconda3_NR\lib\site-packages\urllib3\poolmanager.py:376, in PoolManager.urlopen(self, method, url, redirect, **kw)
#     374     response = conn.urlopen(method, url, **kw)
#     375 else:
# --> 376     response = conn.urlopen(method, u.request_uri, **kw)
#     378 redirect_location = redirect and response.get_redirect_location()
#     379 if not redirect_location:
#
# File ~\anaconda3_NR\lib\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File ~\anaconda3_NR\lib\site-packages\urllib3\connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444             httplib_response = conn.getresponse()
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~\anaconda3_NR\lib\site-packages\urllib3\connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     441 except TypeError:
#     442     # Python 3
#     443     try:
# --> 444         httplib_response = conn.getresponse()
#     445     except BaseException as e:
#     446         # Remove the TypeError from the exception chain in
#     447         # Python 3 (including for exceptions like SystemExit).
#     448         # Otherwise it looks like a bug in the code.
#     449         six.raise_from(e, None)
#
# File ~\anaconda3_NR\lib\http\client.py:1377, in HTTPConnection.getresponse(self)
#    1375 try:
#    1376     try:
# -> 1377         response.begin()
#    1378     except ConnectionError:
#    1379         self.close()
#
# File ~\anaconda3_NR\lib\http\client.py:320, in HTTPResponse.begin(self)
#     318 # read until we get a non-100 response
#     319 while True:
# --> 320     version, status, reason = self._read_status()
#     321     if status != CONTINUE:
#     322         break
#
# File ~\anaconda3_NR\lib\http\client.py:281, in HTTPResponse._read_status(self)
#     280 def _read_status(self):
# --> 281     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     282     if len(line) > _MAXLINE:
#     283         raise LineTooLong("status line")
#
# File ~\anaconda3_NR\lib\socket.py:704, in SocketIO.readinto(self, b)
#     702 while True:
#     703     try:
# --> 704         return self._sock.recv_into(b)
#     705     except timeout:
#     706         self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
driver.quit()  # brower, driver 종료

# %% [markdown]
# - 더 자세한 내용은
# ```
# https://www.selenium.dev/documentation/webdriver/elements/
# ```

# %% [markdown]
# **find_element_by_id**

# %%
driver = webdriver.Chrome()

# %%
driver.get("http://naver.com")

# %%
elem = driver.find_element_by_id('query')

# %%
elem.send_keys("파이썬")

# %%
from selenium.webdriver.common.keys import Keys
elem.send_keys(Keys.ENTER)

# %%
elem = driver.find_element_by_tag_name('a')

# %%
driver.quit()  # brower, driver 종료

# %% [markdown]
# **find_element_by_name**

# %%
driver = webdriver.Chrome()
driver.get("http://naver.com")

# %%
elem = driver.find_element_by_name('query')
elem.send_keys("파이썬")

# %%
elem = driver.find_element_by_id('search_btn')
elem.click()

# %% [markdown]
# **find_element_by_xpath**

# %%
elem = driver.find_element_by_xpath('//*[@id="search_btn"]')
elem.click()

# %%
driver.quit()

# %% [markdown]
# # Element를 찾는 데 필요한 함수들
# # driver.find_element_by_id
# # driver.find_element_by_name
# # driver.find_element_by_tag_name
# # driver.find_element_by_xpath
# # driver.find_element_by_css_selector

# %% [markdown]
# # Workshop 1
#
# - 네이버 로그인

# %%
options = webdriver.ChromeOptions()
options.add_argument('user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/106.0.0.0 Safari/537.36')

driver = webdriver.Chrome(options=options)

# 네이버 사이트 이동
driver.get("http://naver.com")

# %%
# 로그인 버튼
elem = driver.find_element_by_xpath('//*[@id="account"]/a')
elem.click()

# %%
# id / password
elem = driver.find_element_by_id('id')
elem.send_keys("ajtwlsdnrms")

elem = driver.find_element_by_id('pw')
elem.send_keys("wjdrms123!@#")

# %%
# 로그인 버튼
elem = driver.find_element_by_xpath('//*[@id="log.login"]')
elem.click()

# %%
driver.quit()

# %% [markdown]
# ---

# %%
import time

# %%
options = webdriver.ChromeOptions()
options.add_argument('user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/106.0.0.0 Safari/537.36')

driver = webdriver.Chrome(options=options)

# 네이버 사이트 이동
driver.get("http://naver.com")

# %%
# 로그인 버튼
elem = driver.find_element_by_css_selector('a.link_login')
elem.click()

# %%
# id / password
elem = driver.find_element_by_id('id')
elem.send_keys("ajtwlsdnrms")
time.sleep(2)

elem = driver.find_element_by_id('pw')
elem.send_keys("wjdrms123!@#")
time.sleep(1)

elem = driver.find_element_by_id('log.login')
elem.click()

# %%
# 종료
driver.quit()

# %% [markdown]
# # Workshop 2

# %% [markdown]
# **구글 이미지 검색**

# %%
options = webdriver.ChromeOptions()
options.add_argument('user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/106.0.0.0 Safari/537.36')

driver = webdriver.Chrome(options=options)

# 구글 이미지 검색 사이트 이동
driver.get("https://www.google.co.kr/imghp?hl=ko&tab=ri&ogbl")

# %%
keyword = '딸기'
elem = driver.find_element_by_name('q')
elem.send_keys(keyword)
elem.submit()  # elem.send_keys(Keys_ENTER)과 동일

# %%
# 작은 이미지 클릭
image_elem = driver.find_element_by_css_selector('img.rg_i.Q4LuWd')
image_elem.click()

# %%
# 오른쪽에 있는 큰 이미지의 주소를 흭득
image_elem = driver.find_element_by_xpath('//*[@id="Sva75c"]/div/div/div[3]/div[2]/c-wiz/div/div[1]/div[1]/div[3]/div/a/img')
image_url = image_elem.get_attribute('src')
print(image_url)
# Out:
# https://m.nongmin.com/upload/bbs/202202/20220213000003506/20220213000003506.jpg

# %%
# 이미지 주소로 request해서 응답받은 이미지를 저장
import requests

user_agent = "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/106.0.0.0 Safari/537.36"

headers = {"User-Agent": user_agent}
response = requests.get(image_url, headers)
response.raise_for_status()

with open('./strawberry/1.jpg', 'wb') as fd:
            fd.write(response.content)

# %%
options = webdriver.ChromeOptions()
options.add_argument('user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/106.0.0.0 Safari/537.36 Edg/106.0.1370.47')

driver = webdriver.Chrome(options=options)

# 구글 이미지검색 사이트 이동
driver.get("https://www.google.co.kr/imghp?hl=ko&tab=ri&ogbl")

# 검색
keyword = '감자'
elem = driver.find_element_by_name('q')
elem.send_keys(keyword)
elem.submit() # elem.send_keys(Keys.ENTER) 와 동일

# 작은 이미지 클릭
image_elems= driver.find_elements_by_css_selector('img.rg_i.Q4LuWd')

count = 1
for image_elem in image_elems:
    image_elem.click()
    time.sleep(2)

    # 오른쪽에 있는 큰 이미지의 주소를 획득
    image_elem = driver.find_element_by_xpath('//*[@id="Sva75c"]/div/div/div[3]/div[2]/c-wiz/div/div[1]/div[1]/div[3]/div/a/img')
    image_url = image_elem.get_attribute('src')
    print(image_url)

    # 이미지 주소로 request 해서 응답받은 이미지를 저장
    import requests

    user_agent = "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/106.0.0.0 Safari/537.36 Edg/106.0.1370.47"

    headers = {"User-Agent" : user_agent}
    response = requests.get(image_url, headers)
    response.raise_for_status()

    with open('./potato/{}.jpg'.format(count), 'wb') as fd:
                fd.write(response.content)
    count += 1
    if count > 10:
        break
# Out:
# http://health.chosun.com/site/data/img_dir/2020/05/07/2020050702573_0.jpg
# https://mediahub.seoul.go.kr/wp-content/uploads/2016/09/61a2981f41200ac8c513a3cbc0010efe.jpg
# https://static.wikia.nocookie.net/nutri/images/a/af/%EA%B0%90%EC%9E%90.png/revision/latest/scale-to-width-down/1200?cb=20160225185937&path-prefix=ko
# https://img.hankyung.com/photo/202205/01.29875486.1.jpg
# https://www.shinsegaegroupnewsroom.com/wp-content/uploads/2020/07/%EC%9D%B4%EB%A7%88%ED%8A%B813_%EB%B3%B8%EB%AC%B801.png
# https://cdn.travie.com/news/photo/202104/21806_10684_4721.jpg
# http://kormedi.com/wp-content/uploads/2021/07/gettyimages-1255196477-580x409.jpg
# https://cdn.manzlab.com/news/photo/201808/1459_2985_4311.jpg
# https://file.mk.co.kr/meet/neds/2022/03/image_readtop_2022_232180_16471681304973401.jpg
# https://health.chosun.com/site/data/img_dir/2022/03/02/2022030201576_0.jpg

# %%
driver.quit()

# %% [markdown]
# - 사용자의 Scroll 반영

# %%
options = webdriver.ChromeOptions()
options.add_argument('user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/106.0.0.0 Safari/537.36 Edg/106.0.1370.47')

driver = webdriver.Chrome(options=options)

# 구글 이미지검색 사이트 이동
driver.get("https://www.google.co.kr/imghp?hl=ko&tab=ri&ogbl")

# 검색
keyword = '감자'
elem = driver.find_element_by_name('q')
elem.send_keys(keyword)
elem.submit() # elem.send_keys(Keys.ENTER) 와 동일

# Java Script의 스크롤 기능을 통해서 더 많은 이미지를 가져옴
prev_height = driver.execute_script('return document.body.scrollHeight')
print(prev_height)

while True:
    driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')
    time.sleep(1)
    curr_height = driver.execute_script('return document.body.scrollHeight')
    print(curr_height)
    if prev_height == curr_height:
        break
    prev_height = curr_height

# 작은 이미지 클릭
image_elems= driver.find_elements_by_css_selector('img.rg_i.Q4LuWd')

count = 1
for image_elem in image_elems:
    image_elem.click()
    time.sleep(2)

    # 오른쪽에 있는 큰 이미지의 주소를 획득
    image_elem = driver.find_element_by_xpath('//*[@id="Sva75c"]/div/div/div[3]/div[2]/c-wiz/div/div[1]/div[1]/div[3]/div/a/img')
    image_url = image_elem.get_attribute('src')
    print(image_url)

    # 이미지 주소로 request 해서 응답받은 이미지를 저장
    import requests

    user_agent = "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/106.0.0.0 Safari/537.36 Edg/106.0.1370.47"

    headers = {"User-Agent" : user_agent}
    response = requests.get(image_url, headers)
    response.raise_for_status()

    with open('./potato/{}.jpg'.format(count), 'wb') as fd:
                fd.write(response.content)
    count += 1
    if count > 30:
        breakdriver.quit()
# Out:
# 3270
# 6670
# 12736
# 18802
# 24868
# 24949
# 24949
# http://health.chosun.com/site/data/img_dir/2020/05/07/2020050702573_0.jpg
# https://mediahub.seoul.go.kr/wp-content/uploads/2016/09/61a2981f41200ac8c513a3cbc0010efe.jpg
# https://static.wikia.nocookie.net/nutri/images/a/af/%EA%B0%90%EC%9E%90.png/revision/latest/scale-to-width-down/1200?cb=20160225185937&path-prefix=ko
# https://img.hankyung.com/photo/202205/01.29875486.1.jpg
# https://www.shinsegaegroupnewsroom.com/wp-content/uploads/2020/07/%EC%9D%B4%EB%A7%88%ED%8A%B813_%EB%B3%B8%EB%AC%B801.png
# https://cdn.travie.com/news/photo/202104/21806_10684_4721.jpg
# http://kormedi.com/wp-content/uploads/2021/07/gettyimages-1255196477-580x409.jpg
# https://cdn.manzlab.com/news/photo/201808/1459_2985_4311.jpg
# https://file.mk.co.kr/meet/neds/2022/03/image_readtop_2022_232180_16471681304973401.jpg
# https://health.chosun.com/site/data/img_dir/2022/03/02/2022030201576_0.jpg
# https://t1.daumcdn.net/thumb/R720x0/?fname=http://t1.daumcdn.net/brunch/service/user/3mm/image/sknMyUB4sU-_FplAP6ZeainEGF8
# https://image.dongascience.com/Photo/2021/08/53df2dd5a36c58b02c0c2353f65cb5c8.png
# https://img-cf.kurly.com/shop/data/goodsview/20210218/gv30000159355_1.jpg
# https://newsimg.sedaily.com/2019/12/02/1VRX2UQHET_1.jpg
# https://upload.wikimedia.org/wikipedia/commons/thumb/a/a3/234_Solanum_tuberosum_L.jpg/250px-234_Solanum_tuberosum_L.jpg
# https://images.mypetlife.co.kr/content/uploads/2019/10/09152556/lars-blankers-B0s3Xndk6tw-unsplash-1024x683.jpg
# https://blog.kakaocdn.net/dn/cwMiBr/btqDMj3d63f/QKs3YBc6S3blMD38nnwtl0/img.jpg
# https://recipe1.ezmember.co.kr/cache/recipe/2022/02/08/ff66cfd71a3b9d41b26142a410b0cc4d1.jpg
# https://cdn.huffingtonpost.kr/news/photo/201601/21945_42769.jpeg
# https://img-cf.kurly.com/shop/data/goodsview/20210628/gv30000197759_1.jpg
# https://image.yes24.com/goods/105981098/XL
# https://blog.kakaocdn.net/dn/dJSVwV/btrctuINHBf/RgU1SC94TekVy6hiijpct1/img.png
# https://tongsangnews.kr/webzine/2110/assets/images/sub/sub4_2_1.jpg
# https://post-phinf.pstatic.net/MjAxOTA3MDhfODEg/MDAxNTYyNTUyNDU3MjU2.re47TUbcUytgBBT6Pcsnpqz2ZYELS0jRWNm0N_yoYb0g.GEH8hUENjObjG77330lGLIF5x6ncy6vd02brSBN46cog.JPEG/GettyImages-a11228264.jpg?type=w1200
# https://recipe1.ezmember.co.kr/cache/recipe/2021/01/01/66783e2b5ebd0d1936156fe20e20e7561.jpg
# https://image.news1.kr/system/photos/2019/4/26/3618614/article.jpg/dims/optimize
# https://contents.lotteon.com/itemimage/_v140655/LO/19/70/97/82/44/_1/97/09/78/24/5/LO1970978244_1970978245_1.jpg/dims/optimize/dims/resizemc/400x400
# https://file.mk.co.kr/meet/neds/2020/02/image_readtop_2020_187292_15824916624096285.jpg
# https://www.tefal.co.kr/medias/?context=bWFzdGVyfHJvb3R8MTY5OTB8aW1hZ2UvanBlZ3xoZGMvaDI4LzE0MDcwMjQ4Mjc1OTk4LmpwZ3wyOTBmNDZmYmU5NTUwYWE4YmQwMjQyOTdmZjg4YWExYmE2YTQxNjlhYWQ4YmUxNjY1MTcwMjE5MGMwYzBhODQ0
# https://i1.sndcdn.com/artworks-INUNGkM8WJBLLMUl-na88ZQ-t500x500.jpg

# %%
driver.quit()

# %% [markdown]
# **구글 무비**
# - https://play.google.com/store/movies/top
# - 스크롤된 모든 데이터에 대해
# - 가격이 할인된 영화만 출력하되
# - 출력 양식 : 영화제목, 할인전/후 가격, 링크

# %%
# 1. 첫 화면 접속
options = webdriver.ChromeOptions()
options.add_argument('user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/106.0.0.0 Safari/537.36')

driver = webdriver.Chrome(options=options)

driver.get("https://play.google.com/store/movies/top")

# 2. 화면 스크롤
while True:
    driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')
    time.sleep(1)
    curr_height = driver.execute_script('return document.body.scrollHeight')
    print(curr_height)
    if prev_height == curr_height:
        break
    prev_height = curr_height
# Out:
# 2882
# 3270
# 3270

# %%
driver.page_source
# Out:
# '<html lang="ko" dir="ltr"><head><script type="text/javascript" async="" src="https://www.gstatic.com/recaptcha/releases/NJPGLzpIZgjszqyOymHUP0XR/recaptcha__ko.js" crossorigin="anonymous" integrity="sha384-gQ9aVVc923FYwaH8VaOoYNcL8knWCtMdgWqBwXlxaBHvhdH9N5md/j/f3+HkB76O" nonce=""></script><script async="" src="https://www.google-analytics.com/analytics.js" nonce=""></script><base href="https://play.google.com/"><meta name="referrer" content="origin"><meta name="viewport" content="width=device-width, initial-scale=1"><meta name="mobile-web-app-capable" content="yes"><meta name="apple-mobile-web-app-capable" content="yes"><meta name="google-site-verification" content="sBw2N8uateIzRr93vmFze5MF_35vMk5F1wG04L5JcJE"><meta name="google-site-verification" content="PJKdyVFC5jlu_l8Wo_hirJkhs1cmitmn44fgpOc3zFc"><link rel="search" href="/opensearch.xml" type="application/opensearchdescription+xml" title="Google Play"><link rel="shortcut icon" href="//www.gstatic.com/android/market_images/web/favicon_v3.ico"
\\",\\"com.sialiagames.sgzzlb.gp.tw\\",\\"com.stgl.global\\",\\"com.tg.ysczgkr.gp\\",\\"com.tg.ysczgm.gp\\",\\"com.topgamesinc.evony\\",\\"com.topwar.gp\\",\\"com.tortugateam.bravelandheroes\\",\\"com.ubisoft.dance.JustDance\\",\\"com.userjoy.sgc\\",\\"com.webzen.r2m.google\\",\\"com.wemade.mirm\\",\\"com.webzen.r2mtw.google\\" ...

# %%
# 3. 필요한 정보 가져오기 위한 구문 분석
soup = BeautifulSoup(driver.page_source, 'lxml')

# print(soup.prettify)

movies = soup.select('div.VfPpkd-EScbFb-JIbuQc.UVEnyf')

len(movies)

count = 0
for movie in movies:
    # 영화 제목
    title = movie.select_one('div.Epkrse')
    title = title.text

    # 할인 전 가격
    original_price = movie.select_one('span.SUZt4c.P8AFK')
    if original_price:
        original_price = original_price.text
        
    else:    # 할인 전 가격이 없으면 세일하는 항목이 아님 
        continue
    
    # 할인 후 가격
    discount_price = movie.select_one('span.VfPpfd.VixbEe')
    discount_price = discount_price.text

    # 링크 정보
    link = movie.select_one('a.Si6A0c.ZD8Cqc')
    link = 'http://play.google.com' + link['href']
    link
    
    print('제목: ', title)
    print('할인 전 가격: ', original_price)
    print('할인 후 가격: ', discount_price)
    print('링크 정보: ', link)
    print('*' * 100)
    count += 1
print(count)
# Out:
# 제목:  탑건 2 무비 컬렉션
# 할인 전 가격:  ₩13,500
# 할인 후 가격:  ₩12,000
# 링크 정보:  http://play.google.com/store/movies/details/%ED%83%91%EA%B1%B4_2_%EB%AC%B4%EB%B9%84_%EC%BB%AC%EB%A0%89%EC%85%98?id=1aLgJ4syNGk.P
# ****************************************************************************************************
# 제목:  해리포터풀패키지(1-7B)
# 할인 전 가격:  ₩36,000
# 할인 후 가격:  ₩30,400
# 링크 정보:  http://play.google.com/store/movies/details/%ED%95%B4%EB%A6%AC%ED%8F%AC%ED%84%B0%ED%92%80%ED%8C%A8%ED%82%A4%EC%A7%80_1_7B?id=oV2yIteiUjY.P
# ****************************************************************************************************
# 제목:  락다운 213주
# 할인 전 가격:  ₩7,000
# 할인 후 가격:  ₩5,000
# 링크 정보:  http://play.google.com/store/movies/details/%EB%9D%BD%EB%8B%A4%EC%9A%B4_213%EC%A3%BC?id=1xGYLHUpk4E.P
# ****************************************************************************************************
# 제목:  리볼버
# 할인 전 가격:  ₩7,000
# 할인 후 가격:  ₩5,000
# 링크 정보:  http://play.google.com/store/movies/details/%EB%A6%AC%EB%B3%BC%EB%B2%84?id=pB98Q-Rx6pM.P
# ****************************************************************************************************
# 제목:  해리포터풀패키지(1-7B)
# 할인 전 가격:  ₩36,000
# 할인 후 가격:  ₩30,400
# 링크 정보:  http://play.google.com/store/movies/details/%ED%95%B4%EB%A6%AC%ED%8F%AC%ED%84%B0%ED%92%80%ED%8C%A8%ED%82%A4%EC%A7%80_1_7B?id=oV2yIteiUjY.P
# ****************************************************************************************************
# 제목:  해리포터 시리즈 완결 패키지
# 할인 전 가격:  ₩36,000
# 할인 후 가격:  ₩18,900
